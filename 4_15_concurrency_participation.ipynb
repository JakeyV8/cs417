# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeyV8/cs417/blob/main/4_15_concurrency_participation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
for i in range(10):
  print("loop "+str(i))
  print(random.randint(1,10))
  random.seed(10)
  print(random.randint(1,10))
  random.seed(100)
  print(random.randint(1,10))
  random.seed(None)
# Out:
# loop 0
# 10
# 10
# 3
# loop 1
# 7
# 10
# 3
# loop 2
# 3
# 10
# 3
# loop 3
# 9
# 10
# 3
# loop 4
# 1
# 10
# 3
# loop 5
# 2
# 10
# 3
# loop 6
# 4
# 10
# 3
# loop 7
# 10
# 10
# 3
# loop 8
# 4
# 10
# 3
# loop 9
# 7
# 10
# 3
